# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("download.jpg")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (237, 212, 3)

# %%
cut = arr[:5,:5]

# %%
plt.imshow(cut)

# %%
grey = arr.mean(axis =2)

# %%
plt.imshow(grey, cmap ="gray")

# %%
work = arr.copy()

# %%
work[: ,: ,[1,2]].shape
# Out:
# (237, 212, 2)

# %%
work[: ,: ,[1,2]]
# Out:
# array([[[ 66,  58],
#         [ 66,  58],
#         [ 67,  59],
#         ...,
#         [ 85,  69],
#         [ 85,  69],
#         [ 85,  69]],
#
#        [[ 67,  59],
#         [ 67,  59],
#         [ 67,  59],
#         ...,
#         [ 86,  70],
#         [ 86,  70],
#         [ 86,  70]],
#
#        [[ 68,  60],
#         [ 68,  60],
#         [ 68,  60],
#         ...,
#         [ 85,  70],
#         [ 85,  70],
#         [ 85,  70]],
#
#        ...,
#
#        [[133, 112],
#         [148, 126],
#         [144, 120],
#         ...,
#         [  9,  10],
#         [  9,  10],
#         [  9,  10]],
#
#        [[133, 115],
#         [141, 120],
#         [121,  99],
#         ...,
#         [  9,  10],
#         [  9,  10],
#         [  9,  10]],
#
#        [[118, 100],
#         [123, 105],
#         [ 93,  72],
#         ...,
#         [  9,  10],
#         [  9,  10],
#         [  9,  10]]], dtype=uint8)

# %%
work[: ,: ,[1,2]] = 0

# %%
plt.imshow(work)
